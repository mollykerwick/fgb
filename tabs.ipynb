# %%
# %pylab inline
import tabs
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#df = tabs.read('face', '1999-1-1', '1999-1-5', model=True, s_rho=10)
df = tabs.read('N', '2017-7-1', '2018-7-19', model=True, s_rho=10)

# %%
df
# Out:
#                            N: Along [cm/s]  N: Across [cm/s]  \
# Dates [UTC]
# 2018-01-18 00:00:00+00:00              NaN               NaN
# 2018-01-18 01:00:00+00:00              NaN               NaN
# 2018-01-18 02:00:00+00:00              NaN               NaN
# 2018-01-18 03:00:00+00:00              NaN               NaN
# 2018-01-18 04:00:00+00:00              NaN               NaN
# 2018-01-18 05:00:00+00:00              NaN               NaN
# 2018-01-18 06:00:00+00:00              NaN               NaN
# 2018-01-18 07:00:00+00:00              NaN               NaN
# 2018-01-18 08:00:00+00:00              NaN               NaN
# 2018-01-18 09:00:00+00:00              NaN               NaN
# 2018-01-18 10:00:00+00:00              NaN               NaN
# 2018-01-18 11:00:00+00:00              NaN               NaN
# 2018-01-18 12:00:00+00:00              NaN               NaN
# 2018-01-18 13:00:00+00:00              NaN               NaN
# ...

# %% [markdown]
# Earliest data:
# - N: 2018-01-18
# - V: 2018-01-18
#
# Latest data:
# - N: 2018-07-16
# - V: 2018-07-16

# %%
df["V: Salinity"].plot()

# %%
tabs.read?
