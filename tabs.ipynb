# %%
# %pylab inline
import tabs
import cmocean as cmo
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/anaconda3/lib/python3.6/site-packages/cmocean/tools.py:76: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not mpl.cbook.is_string_like(rgbin[0]):

# %%
df = tabs.read('V', '2012-5-1', '2016-9-1', model=True, s_rho=-999)

# %%
times = np.linspace(5, 8, 2209)

# %%
66270/30
# Out:
# 2209.0

# %%
salt13 = df['2013-5-1 1:00:00':'2013-8-1 1:00:00'][["V: Salinity"]].values.reshape(2209,30)
salt16 = df['2016-5-1 1:00:00':'2016-8-1 1:00:00'][["V: Salinity"]].values.reshape(2209,30)


temp13 = df['2013-5-1 1:00:00':'2013-8-1 1:00:00'][["V: WaterT [deg C]"]].values.reshape(2209,30)
temp16 = df['2016-5-1 1:00:00':'2016-8-1 1:00:00'][["V: WaterT [deg C]"]].values.reshape(2209,30)


# V: Density [kg/m^3]
dens13 = df['2013-5-1 1:00:00':'2013-8-1 1:00:00'][["V: Density [kg/m^3]"]].values.reshape(2209,30)
dens16 = df['2016-5-1 1:00:00':'2016-8-1 1:00:00'][["V: Density [kg/m^3]"]].values.reshape(2209,30)

# %% [markdown]
# # Salinity

# %%
plt.contourf( depths*-1, times, salt13 )
plt.colorbar()
plt.show()

plt.contourf( depths*-1, times, salt16 )
plt.colorbar()
plt.show()

# %% [markdown]
# # Temperature

# %%
plt.contourf( depths*-1, times, temp13 )
plt.colorbar()
plt.show()

plt.contourf( depths*-1, times, temp16 )
plt.colorbar()
plt.show()

# %% [markdown]
# # Density

# %%
plt.contourf( depths*-1, times, dens13 )
plt.colorbar()
plt.show()

plt.contourf( depths*-1, times, dens16 )
plt.colorbar()
plt.show()

# %%
df.columns
# Out:
# Index(['V: Depth [m]', 'V: Along [cm/s]', 'V: Across [cm/s]',
#        'V: WaterT [deg C]', 'V: Salinity',
#        'V: Dissolved oxygen concentration [uM]',
#        'V: Mississippi passive tracer', 'V: Atchafalaya passive tracer',
#        'V: Brazos passive tracer', 'V: w', 'V: Density [kg/m^3]',
#        'V: East [cm/s]', 'V: North [cm/s]'],
#       dtype='object')

# %%
df2 = tabs.read('V', '2008-5-1', '2008-5-31', model=True, s_rho=-999)

# %%
df2["V: Depth [m]"]
# Out:
# Dates [UTC]
# 2008-05-01 01:00:00+00:00   -4.86
# 2008-05-01 01:00:00+00:00   -4.60
# 2008-05-01 01:00:00+00:00   -4.35
# 2008-05-01 01:00:00+00:00   -4.11
# 2008-05-01 01:00:00+00:00   -3.88
# 2008-05-01 01:00:00+00:00   -3.67
# 2008-05-01 01:00:00+00:00   -3.47
# 2008-05-01 01:00:00+00:00   -3.27
# 2008-05-01 01:00:00+00:00   -3.08
# 2008-05-01 01:00:00+00:00   -2.90
# 2008-05-01 01:00:00+00:00   -2.73
# 2008-05-01 01:00:00+00:00   -2.56
# 2008-05-01 01:00:00+00:00   -2.40
# 2008-05-01 01:00:00+00:00   -2.24
# 2008-05-01 01:00:00+00:00   -2.08
# 2008-05-01 01:00:00+00:00   -1.93
# 2008-05-01 01:00:00+00:00   -1.77
# 2008-05-01 01:00:00+00:00   -1.62
# 2008-05-01 01:00:00+00:00   -1.48
# 2008-05-01 01:00:00+00:00   -1.33
# 2008-05-01 01:00:00+00:00   -1.19
# 2008-05-01 01:00:00+00:00   -1.04
# 2008-05-01 01:00:00+00:00   -0.90
# 2008-05-01 01:00:00+00:00   -0.76
# 2008-05-01 01:00:00+00:00   -0.62
# 2008-05-01 01:00:00+00:00   -0.48
# 2008-05-01 01:00:00+00:00   -0.34
# ...

# %% [markdown]
# `s_rho` goes from 0 to 29

# %%
plt.plot(salinity[0])

# %% [markdown]
# Earliest data:
# - N: 2018-01-18
# - V: 2018-01-18
#
# Latest data:
# - N: 2018-07-19
# - V: 2018-07-19

# %%
df["V: Salinity"].plot()

# %%
df["V: Salinity"].plot()

# %%
tabs.read?

# %%
plt.plot?
