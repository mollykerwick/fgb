# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import datetime
matplotlib.rcParams.update({'font.size': 20})
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
filename = "efgb_salinity_1col.csv"
df = pd.read_csv(filename, parse_dates=[0], index_col=0)

df
# Out:
#          24 m SBE               TABS
# Date    EFGB 2008  Surface TABS Buoy
# 1-Jan         NaN              36.42
# 2-Jan         NaN              36.41
# 3-Jan         NaN              36.42
# 4-Jan         NaN              36.42
# 5-Jan         NaN              36.43
# 6-Jan         NaN              36.43
# 7-Jan         NaN              36.40
# 8-Jan         NaN              36.44
# 9-Jan         NaN              36.46
# 10-Jan        NaN              36.46
# 11-Jan        NaN              36.44
# 12-Jan        NaN              36.45
# 13-Jan        NaN              36.46
# 14-Jan        NaN              36.44
# 15-Jan        NaN              36.39
# 16-Jan        NaN              36.42
# 17-Jan        NaN              36.44
# 18-Jan        NaN              36.45
# 19-Jan        NaN              36.46
# 20-Jan        NaN              36.45
# 21-Jan        NaN              36.45
# 22-Jan        NaN              36.45
# 23-Jan        NaN              36.46
# ...

# %%
ax = df['24 m SBE'][1:].astype(float).plot( figsize=(10,5) )
times = [str(i) for i in range(2008,2017)]
ax.set_xticks( np.arange(0, 3295-365,365) );
ax.set_xticklabels( times, rotation=30 );
ax.set_title( "Salinity from 24m sensors on East Bank", fontsize=24 )
# Out:
# Text(0.5,1,'Salinity from 24m sensors on East Bank')
